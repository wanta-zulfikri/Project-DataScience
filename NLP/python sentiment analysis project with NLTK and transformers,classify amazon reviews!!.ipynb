# %% [markdown]
# Step 0. Read in Data and NLTK Basics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\LENOVO
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\LENOVO PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\LENOVO
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to C:\Users\LENOVO
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to C:\Users\LENOVO
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# read in data 
df = pd.read_csv('Reviews.csv')
print(df.shape)
df = df.head(500)
print(df.shape)
# Out:
# (568454, 10)
# (500, 10)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# Quick EDA

# %%
ax = df['Score'].value_counts().sort_index() \
     .plot(kind='bar',
           title='Count of Reviews by Stars',
           figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %% [markdown]
# Basic NLTK

# %%
example = df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# Step 1. VADER Seniment Scoring
# we will use NLTK's SentimentIntensityAnalyzer to get the neg/neu/pos scores of the text.
#
#   This uses a "bag of words" approach:
#      1. Stop words are removed
#      2. each word is scored and combined to a total score.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever.')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# run the polarity score on the entire dataset 
res = {} 
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, how='left')

# %%
# Now we have sentiment score and metadata
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %% [raw]
# Plot VADER results

# %%
ax = sns.barplot(data=vaders, x='Score', y='compound')
ax.set_title('Compund Score by Amazon Star Review')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [raw]
# Step 3.Roberta Pretrained Model
#  use a model trained of a large corpus of data.
#  Transformer model accounts for the words but also the context related to other words.

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\lenovo pc\anaconda3\lib\site-packages (4.22.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.9.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers) (0.9.1)
# Requirement already satisfied: requests in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: filelock in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo pc\appdata\roaming\python\python39\site-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers) (1.21.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo pc\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.9.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lenovo pc\appdata\roaming\python\python39\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\lenovo pc\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo pc\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo pc\anaconda3\lib\site-packages (from requests->transformers) (2022.9.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install spacy-transformers
# Out:
# Requirement already satisfied: spacy-transformers in c:\users\lenovo pc\anaconda3\lib\site-packages (1.1.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy-transformers) (2.4.5)
# Requirement already satisfied: spacy<4.0.0,>=3.4.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy-transformers) (3.4.2)
# Collecting transformers<4.22.0,>=3.4.0
#   Using cached transformers-4.21.3-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: torch>=1.6.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy-transformers) (1.10.2)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy-transformers) (0.8.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.21.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (4.64.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (8.1.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo pc\appdata\roaming\python\python39\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (21.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.10.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (0.10.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.11.3)
# Requirement already satisfied: setuptools in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (61.2.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.27.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\lenovo pc\anaconda3\lib\site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lenovo pc\appdata\roaming\python\python39\site-packages (from packaging>=20.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<4.0.0,>=3.4.0->spacy-transformers) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<4.0.0,>=3.4.0->spacy-transformers) (4.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (2022.9.14)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (1.26.9)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\lenovo pc\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (0.0.3)
# Requirement already satisfied: colorama in c:\users\lenovo pc\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (0.4.4)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (0.12.1)
# Requirement already satisfied: filelock in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (3.6.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (0.9.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo pc\anaconda3\lib\site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (2022.3.15)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\lenovo pc\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lenovo pc\anaconda3\lib\site-packages (from jinja2->spacy<4.0.0,>=3.4.0->spacy-transformers) (2.0.1)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.22.1
#     Uninstalling transformers-4.22.1:
#       Successfully uninstalled transformers-4.22.1
# Successfully installed transformers-4.21.3

# %%
# !python -m spacy download en_trf_bertbaseuncased_lg
# Out:
# [x] No compatible package found for 'en_trf_bertbaseuncased_lg' (spaCy v3.4.2)

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification

from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
#VADER result on example 
print(example)
sia.polarity_scores(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run for Roberta Model
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.9763551, 'roberta_neu': 0.020687481, 'roberta_pos': 0.002957373}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Broke for id 83
# Broke for id 187

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(df, how='left')

# %% [raw]
# Step 3.Compare Score between models

# %%
sns.pairplot(data=results_df,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Score',
            palette='tab10')
plt.show()

# %% [raw]
# Step 4: Review Examples:
#
#   positive 1-Star and Negative 5-Star Reviews
#   lets look at some examples where the model scoring and review score differ the most.

# %%
results_df.query('Score == 1') \
    .sort_values('roberta_pos', ascending=False)['Text'].values[0]
# Out:
# 'I felt energized within five minutes, but it lasted for about 45 minutes. I paid $3.99 for this drink. I could have just drunk a cup of coffee and saved my money.'

# %%
results_df.query('Score == 1') \
    .sort_values('vader_pos', ascending=False)['Text'].values[0]
# Out:
# 'So we cancelled the order.  It was cancelled without any problem.  That is a positive note...'

# %% [raw]
# # nevative sentiment 5-Star view

# %%
results_df.query('Score == 5') \
    .sort_values('roberta_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %%
results_df.query('Score == 5') \
    .sort_values('vader_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %% [raw]
# Extra: The Transformers Pipeline
#
# quick & easy way to run sentiment predictions

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %%
sent_pipeline('I love sentiment analysis!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9997853636741638}]

# %%
sent_pipeline('Make sure to like and subscribe!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9991742968559265}]

# %%
sent_pipeline('booo')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9936267137527466}]
